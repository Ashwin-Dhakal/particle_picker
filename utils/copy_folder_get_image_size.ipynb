# %%
import shutil
from shutil import copy2
src_path = r"/bml/ashwin/ViTPicker/data_collection/10345_10406/train/"
dst_path = r"/bml/ashwin/ViTPicker/train_val_data/train/"

# %%
from distutils.dir_util import copy_tree
copy_tree(src_path, dst_path)
# Out:
# ['/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0007_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0008_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0009_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0010_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0011_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0012_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0013_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0014_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0022_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0023_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0024_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0025_ali_DW.jpg',
#  '/bml/ashwin/ViTPicker/train_val_data/train/18jam15a_0026_ali_DW.jpg',
# ...

# %%
# find image size

image_10028 = r"/bml/ashwin/ViTPicker/data_collection/10028/train/068.jpg"
image_10077 = r"/bml/ashwin/ViTPicker/data_collection/10077/train/sb1_210512 pos 1015 2-2_1.jpg"
image_10081 = r"/bml/ashwin/ViTPicker/data_collection/10081/train/HCN1apo_0008_2xaligned.jpg"
image_10345 = r"/bml/ashwin/ViTPicker/data_collection/10345_10406/train/18jam15a_0007_ali_DW.jpg"
image_10406 = r"/bml/ashwin/ViTPicker/data_collection/10345_10406/train/FoilHole_3165034_Data_3165659_3165660_20190104_1554-61004.jpg"

# %%
height, width = image.shape

# %%
import cv2
image_10028 = cv2.imread(image_10028)
image_10077 = cv2.imread(image_10077)
image_10081 = cv2.imread(image_10081)
image_10345 = cv2.imread(image_10345)
image_10406 = cv2.imread(image_10406)

# %%
height, width, channel = image_10406.shape
print(height, width, channel)
# Out:
# 3710 3838 3
