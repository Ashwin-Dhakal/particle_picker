# %%
import os
import glob
from tqdm import tqdm

# %%
coord_path = sorted(list(glob.glob('/media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/*.jpg')))
for files in coord_path:
    print(files)
# Out:
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0317_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0318_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0319_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0320_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0321_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0322_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0325_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0328_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0329_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/val/18jam15a_0330_ali_DW.jpg
# ...

# %%
coord_path = sorted(list(glob.glob('/media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/*.csv')))
for files in coord_path:
    print(files)
# Out:
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0007_ali_DW.csv
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0008_ali_DW.csv
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0009_ali_DW.csv
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0010_ali_DW.csv
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0011_ali_DW.csv
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0012_ali_DW.csv
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0013_ali_DW.csv
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0014_ali_DW.csv
# ...

# %%
if not os.path.exists(coord_path):
    print(f"coordinates not avaibale for {file_name}.jpg ----> Skipping Image ID : {image_id}")

# %%
for files in coord_path:
    image_name = os.path.join(coord_file_path, '') + files[:-4] + '.jpg'
    print(image_name)
# Out:
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0007_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0008_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0009_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0010_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0011_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0012_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0013_ali_DW.jpg
# /media/ashwin/data2/ViTPicker_data/detr_train_val_data_coord_missing/particle_coordinates/18jam15a_0014_ali_DW.jpg
# ...
